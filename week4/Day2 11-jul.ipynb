# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame({'name':['lalshman','jenny'],
               'rlno':[20,60],
               'branch':['CSE','EEE']})
df
# Out:
#        name  rlno branch
# 0  lalshman    20    CSE
# 1     jenny    60    EEE

# %%
# to rename single column name
df.rename(columns={'rlno':"RLNO"},inplace=True)
df
# Out:
#        name  RLNO branch
# 0  lalshman    20    CSE
# 1     jenny    60    EEE

# %%
import pandas as pd
df=pd.DataFrame({'name':['lalshman','jenny'],
               'rlno':[20,60],
               'branch':['CSE','EEE']})
df.rename(columns={'branch':'Branch'},inplace=True)
df
# Out:
#        name  rlno Branch
# 0  lalshman    20    CSE
# 1     jenny    60    EEE

# %%
# to rename all the column names
df.columns=['NAME','ROLLNO','BRANCH']
df
# Out:
#        NAME  ROLLNO BRANCH
# 0  lalshman      20    CSE
# 1     jenny      60    EEE

# %%
df.index=['A','B'] # change index names
df
# Out:
#        NAME  ROLLNO BRANCH
# A  lalshman      20    CSE
# B     jenny      60    EEE

# %%
df=pd.DataFrame(np.array([[1,2,3],[4,5,6]]))
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
df.drop(df.index,inplace=True)# delete all rows
df
# Out:
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []

# %%
df.drop(df.columns,inplace=True,axis=1)# delete all the columns
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### file input/output reading in pandas:

# %%
# to read .csv file data
df2 = pd.read_csv('data.csv')
df2
# Out:
#      name  rollno branch  java  python
# 0   kalam     240    cse    75      88
# 1     ram     236    ece    69      80
# 2    john     252    cse    50      65
# 3   dhruv     248    eee    65      82
# 4     raj     222  civil    60      50
# 5  ganesh     234   mech    57      63
# 6   varun     233    ece    55      68
# 7    ravi     450   mech    55      80
# 8   kavya     240  civil    59      77

# %%
df2.shape
# Out:
# (9, 5)

# %%
df2.columns
# Out:
# Index(['name', 'rollno', 'branch', 'java', 'python'], dtype='object')

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
df2.max()
# Out:
# name      varun
# rollno      450
# branch     mech
# java         75
# python       88
# dtype: object

# %%
df2['java'].max()
# Out:
# 75

# %%
# print names in order
df2.sort_values('name')
# Out:
#      name  rollno branch  java  python
# 3   dhruv     248    eee    65      82
# 5  ganesh     234   mech    57      63
# 2    john     252    cse    50      65
# 0   kalam     240    cse    75      88
# 8   kavya     240  civil    59      77
# 4     raj     222  civil    60      50
# 1     ram     236    ece    69      80
# 7    ravi     450   mech    55      80
# 6   varun     233    ece    55      68

# %%
print(df2.sort_values(by='name'))
# Out:
#      name  rollno branch  java  python
# 3   dhruv     248    eee    65      82
# 5  ganesh     234   mech    57      63
# 2    john     252    cse    50      65
# 0   kalam     240    cse    75      88
# 8   kavya     240  civil    59      77
# 4     raj     222  civil    60      50
# 1     ram     236    ece    69      80
# 7    ravi     450   mech    55      80
# 6   varun     233    ece    55      68

# %%
df2.sort_values('java',ascending=False)
# Out:
#      name  rollno branch  java  python
# 0   kalam     240    cse    75      88
# 1     ram     236    ece    69      80
# 3   dhruv     248    eee    65      82
# 4     raj     222  civil    60      50
# 8   kavya     240  civil    59      77
# 5  ganesh     234   mech    57      63
# 6   varun     233    ece    55      68
# 7    ravi     450   mech    55      80
# 2    john     252    cse    50      65

# %%
# to sort multiple columns
df2.sort_values(['java','python'])
# Out:
#      name  rollno branch  java  python
# 2    john     252    cse    50      65
# 6   varun     233    ece    55      68
# 7    ravi     450   mech    55      80
# 5  ganesh     234   mech    57      63
# 8   kavya     240  civil    59      77
# 4     raj     222  civil    60      50
# 3   dhruv     248    eee    65      82
# 1     ram     236    ece    69      80
# 0   kalam     240    cse    75      88

# %%
# to add two subject marks
df2['total']=df2['java']+df2['python']
df2
# Out:
#      name  rollno branch  java  python  total
# 0   kalam     240    cse    75      88    163
# 1     ram     236    ece    69      80    149
# 2    john     252    cse    50      65    115
# 3   dhruv     248    eee    65      82    147
# 4     raj     222  civil    60      50    110
# 5  ganesh     234   mech    57      63    120
# 6   varun     233    ece    55      68    123
# 7    ravi     450   mech    55      80    135
# 8   kavya     240  civil    59      77    136

# %%
df2.loc[(df2['java']>55) & (df2['python']>55)]
# Out:
#      name  rollno branch  java  python  total
# 0   kalam     240    cse    75      88    163
# 1     ram     236    ece    69      80    149
# 3   dhruv     248    eee    65      82    147
# 5  ganesh     234   mech    57      63    120
# 8   kavya     240  civil    59      77    136

# %% [markdown]
# #### filtering

# %%
df2
# Out:
#      name  rollno branch  java  python  total
# 0   kalam     240    cse    75      88    163
# 1     ram     236    ece    69      80    149
# 2    john     252    cse    50      65    115
# 3   dhruv     248    eee    65      82    147
# 4     raj     222  civil    60      50    110
# 5  ganesh     234   mech    57      63    120
# 6   varun     233    ece    55      68    123
# 7    ravi     450   mech    55      80    135
# 8   kavya     240  civil    59      77    136

# %%
df2['java'].min()
# Out:
# 50

# %%
df2['python'].max()
# Out:
# 88

# %%
df2['course']=['DJANGO','PYTHON','JAVA','C++','C','HTML','SQL','DBMS','DATA SCIENCE']
df2
# Out:
#      name  rollno branch  java  python  total        course
# 0   kalam     240    cse    75      88    163        DJANGO
# 1     ram     236    ece    69      80    149        PYTHON
# 2    john     252    cse    50      65    115          JAVA
# 3   dhruv     248    eee    65      82    147           C++
# 4     raj     222  civil    60      50    110             C
# 5  ganesh     234   mech    57      63    120          HTML
# 6   varun     233    ece    55      68    123           SQL
# 7    ravi     450   mech    55      80    135          DBMS
# 8   kavya     240  civil    59      77    136  DATA SCIENCE

# %%
df2['course'].value_counts()
# Out:
# DJANGO          1
# PYTHON          1
# JAVA            1
# C++             1
# C               1
# HTML            1
# SQL             1
# DBMS            1
# DATA SCIENCE    1
# Name: course, dtype: int64

# %%
df2['java'].value_counts()
# Out:
# 55    2
# 75    1
# 69    1
# 50    1
# 65    1
# 60    1
# 57    1
# 59    1
# Name: java, dtype: int64

# %%
df2[df2['java']==55]
# Out:
#     name  rollno branch  java  python  total course
# 6  varun     233    ece    55      68    123    SQL
# 7   ravi     450   mech    55      80    135   DBMS

# %%
# cse records
df2[df2['branch']=='cse']
# Out:
#     name  rollno branch  java  python  total  course
# 0  kalam     240    cse    75      88    163  DJANGO
# 2   john     252    cse    50      65    115    JAVA

# %%
# student name start with r
df2[df2['name'].str.startswith('r')]
# Out:
#    name  rollno branch  java  python  total  course
# 1   ram     236    ece    69      80    149  PYTHON
# 4   raj     222  civil    60      50    110       C
# 7  ravi     450   mech    55      80    135    DBMS

# %%
# student name end with m
df2[df2['name'].str.endswith('m')]
# Out:
#     name  rollno branch  java  python  total  course
# 0  kalam     240    cse    75      88    163  DJANGO
# 1    ram     236    ece    69      80    149  PYTHON

# %%
# highest total marks student record from df
df2[df2['total']==df2['total'].max()]
# Out:
#     name  rollno branch  java  python  total  course
# 0  kalam     240    cse    75      88    163  DJANGO

# %%
df3=df2.sort_values('total',ascending=False)
df3.head(1)
# Out:
#     name  rollno branch  java  python  total  course
# 0  kalam     240    cse    75      88    163  DJANGO

# %%
df2 = pd.read_csv('data.csv')
df2.rename(columns={'name':'Name'},inplace=True)
df2
# Out:
#      Name  rollno branch  java  python
# 0   kalam     240    cse    75      88
# 1     ram     236    ece    69      80
# 2    john     252    cse    50      65
# 3   dhruv     248    eee    65      82
# 4     raj     222  civil    60      50
# 5  ganesh     234   mech    57      63
# 6   varun     233    ece    55      68
# 7    ravi     450   mech    55      80
# 8   kavya     240  civil    59      77

# %%
import pandas as pd

# %%
df=pd.read_csv('trade.csv')

# %%
df
# Out:
#       t1     t2   t1views   t2views
# 0   10:2  10:17  50197814  50200520
# 1  10:17  10:20  50200520  50202715
# 2  10:20  10:27  50202715  50205665
# 3  10:27  10:32  50205665  50210356
# 4  10:32  10:36  50210356  50215203
# 5  10:36  10:42  50215203  50220931
# 6  10:42  10:49  50220913  50227038
# 7  10:49  10:51  50227038  50231191

# %%
df['timeinerval']=df['t2']+'-'+df['t1']
df
# Out:
#       t1     t2   t1views   t2views  timeinerval
# 0   10:2  10:17  50197814  50200520   10:17-10:2
# 1  10:17  10:20  50200520  50202715  10:20-10:17
# 2  10:20  10:27  50202715  50205665  10:27-10:20
# 3  10:27  10:32  50205665  50210356  10:32-10:27
# 4  10:32  10:36  50210356  50215203  10:36-10:32
# 5  10:36  10:42  50215203  50220931  10:42-10:36
# 6  10:42  10:49  50220913  50227038  10:49-10:42
# 7  10:49  10:51  50227038  50231191  10:51-10:49

# %%
df['viewsincreased']=df['t2views']-df['t1views']
df
# Out:
#       t1     t2   t1views   t2views  timeinerval  viewsincreased
# 0   10:2  10:17  50197814  50200520   10:17-10:2            2706
# 1  10:17  10:20  50200520  50202715  10:20-10:17            2195
# 2  10:20  10:27  50202715  50205665  10:27-10:20            2950
# 3  10:27  10:32  50205665  50210356  10:32-10:27            4691
# 4  10:32  10:36  50210356  50215203  10:36-10:32            4847
# 5  10:36  10:42  50215203  50220931  10:42-10:36            5728
# 6  10:42  10:49  50220913  50227038  10:49-10:42            6125
# 7  10:49  10:51  50227038  50231191  10:51-10:49            4153
