# %%
import pandas as pd

# %% [markdown]
# * standardizing data(column wise/label wise/feature wise)
# * standard format refers to data that has 0 mean and unit variance(standard deviation=1),the process of converting data into this format is called data standardization

# %%
df=pd.read_csv('Advertising.csv')
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
import seaborn as sns

# %%
sns.kdeplot(df['TV']) # kernel density plot to display how raw data is distributed
sns.kdeplot(df['radio'])
sns.kdeplot(df['newspaper'])
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Density'>

# %%
df.loc[0,'TV']
# Out:
# 230.1

# %%
# std_data=(x-mean(x))/std(x)
(df['TV'][0]-df['TV'].mean())/df['TV'].std()
# Out:
# 0.9674245973763037

# %%
from sklearn.preprocessing import scale

# %%
scl=scale(df)
scl
# Out:
# array([[ 9.69852266e-01,  9.81522472e-01,  1.77894547e+00,
#          1.55205313e+00],
#        [-1.19737623e+00,  1.08280781e+00,  6.69578760e-01,
#         -6.96046111e-01],
#        [-1.51615499e+00,  1.52846331e+00,  1.78354865e+00,
#         -9.07405869e-01],
#        [ 5.20496822e-02,  1.21785493e+00,  1.28640506e+00,
#          8.60330287e-01],
#        [ 3.94182198e-01, -8.41613655e-01,  1.28180188e+00,
#         -2.15683025e-01],
#        [-1.61540845e+00,  1.73103399e+00,  2.04592999e+00,
#         -1.31091086e+00],
#        [-1.04557682e+00,  6.43904671e-01, -3.24708413e-01,
#         -4.27042783e-01],
#        [-3.13436589e-01, -2.47406325e-01, -8.72486994e-01,
#         -1.58039455e-01],
#        [-1.61657614e+00, -1.42906863e+00, -1.36042422e+00,
#         -1.77205942e+00],
#        [ 6.16042873e-01, -1.39530685e+00, -4.30581584e-01,
#         -6.57617064e-01],
#        [-9.45155670e-01, -1.17923146e+00, -2.92486143e-01,
#         -1.04190753e+00],
# ...

# %%
scl_data=pd.DataFrame(scl,columns=df.columns)
scl_data
# Out:
#            TV     radio  newspaper     sales
# 0    0.969852  0.981522   1.778945  1.552053
# 1   -1.197376  1.082808   0.669579 -0.696046
# 2   -1.516155  1.528463   1.783549 -0.907406
# 3    0.052050  1.217855   1.286405  0.860330
# 4    0.394182 -0.841614   1.281802 -0.215683
# ..        ...       ...        ...       ...
# 195 -1.270941 -1.321031  -0.771217 -1.234053
# 196 -0.617035 -1.240003  -1.033598 -0.830548
# 197  0.349810 -0.942899  -1.111852 -0.234898
# 198  1.594565  1.265121   1.640850  2.205347
# 199  0.993206 -0.990165  -1.005979 -0.119610
#
# [200 rows x 4 columns]

# %%
sns.kdeplot(scl_data['TV'])
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Density'>

# %%
df.mean()
# Out:
# TV           147.0425
# radio         23.2640
# newspaper     30.5540
# sales         14.0225
# dtype: float64

# %%
scl_data.mean().round(3)
# Out:
# TV           0.0
# radio       -0.0
# newspaper    0.0
# sales       -0.0
# dtype: float64

# %%
df.std()
# Out:
# TV           85.854236
# radio        14.846809
# newspaper    21.778621
# sales         5.217457
# dtype: float64

# %%
scl_data.std().round(3)
# Out:
# TV           1.003
# radio        1.003
# newspaper    1.003
# sales        1.003
# dtype: float64

# %% [markdown]
# ### 2.Data Range
# * it is done based on colum or label or feature wise.
# * scale data by compressing it into a fixed range.
# * one of the biggest usecase for this is compressing data into range[0,1]
# * MinMaxScaler
# * (x-dmin)/(dmax-dmin)

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mscl=MinMaxScaler()

# %%
mnscale=mscl.fit_transform(df)
mnscale
# Out:
# array([[0.77578627, 0.76209677, 0.60598065, 0.80708661],
#        [0.1481231 , 0.79233871, 0.39401935, 0.34645669],
#        [0.0557998 , 0.92540323, 0.60686016, 0.30314961],
#        [0.50997633, 0.83266129, 0.51187335, 0.66535433],
#        [0.60906324, 0.21774194, 0.51099384, 0.44488189],
#        [0.02705445, 0.9858871 , 0.65699208, 0.22047244],
#        [0.19208657, 0.66129032, 0.20404573, 0.4015748 ],
#        [0.4041258 , 0.39516129, 0.09938434, 0.45669291],
#        [0.02671627, 0.04233871, 0.00615655, 0.12598425],
#        [0.67331755, 0.05241935, 0.18381706, 0.35433071],
#        [0.2211701 , 0.11693548, 0.21020229, 0.27559055],
#        [0.72370646, 0.48387097, 0.03254178, 0.62204724],
#        [0.07811972, 0.70766129, 0.5769569 , 0.2992126 ],
#        [0.32735881, 0.15322581, 0.06068602, 0.31889764],
#        [0.68785932, 0.66330645, 0.40193492, 0.68503937],
#        [0.65843761, 0.96169355, 0.46262093, 0.81889764],
# ...

# %%
mnscale.min()
# Out:
# 0.0

# %%
mnscale.max()
# Out:
# 1.0

# %%
df.min()
# Out:
# TV           0.7
# radio        0.0
# newspaper    0.3
# sales        1.6
# dtype: float64

# %%
df.max()
# Out:
# TV           296.4
# radio         49.6
# newspaper    114.0
# sales         27.0
# dtype: float64

# %% [markdown]
# ##### normalizing data
# * scalimg is done based on individual rows
# * want to scale the individual data observations(rows).
# * used in classification problems and data mining
# * when clustering data we need to apply l2 normalization to each row
# * l2 normalization is applied to particular row of data array
# * l2 norm of a row is squareroot of sum of squared values for the row

# %%
hm=pd.read_csv('HomeBuyer.csv')
hm
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
from sklearn.preprocessing import Normalizer

# %%
norm=Normalizer()

# %%
nor_data=norm.fit_transform(hm)
nor_data
# Out:
# array([[9.99999500e-04, 9.99999500e-01, 0.00000000e+00],
#        [1.74999732e-03, 9.99998469e-01, 0.00000000e+00],
#        [6.04651052e-04, 9.99999817e-01, 0.00000000e+00],
#        ...,
#        [2.49999218e-03, 9.99996874e-01, 4.99998437e-05],
#        [1.09090844e-03, 9.99999405e-01, 0.00000000e+00],
#        [1.36110985e-03, 9.99999073e-01, 2.77777520e-05]])

# %%
nor_data.min()
# Out:
# 0.0

# %%
nor_data.max()
# Out:
# 0.9999999807797668

# %% [markdown]
# ##### robust scaling
# * deals with outliers()

# %%
import pandas as pd
df=pd.read_csv('Salary_Data.csv')
df
# Out:
#        Age  Gender      Qualification                    job  Experience  \
# 0     32.0    Male         Bachelor's      Software Engineer         5.0
# 1     28.0  Female                PHD           Data Analyst         3.0
# 2     45.0    Male                PHD         Senior Manager        15.0
# 3     36.0  Female                PHD        Sales Associate         NaN
# 4     52.0    Male           Master's               Director        20.0
# ...    ...     ...                ...                    ...         ...
# 6699  49.0  Female                PhD  Director of Marketing        20.0
# 6700  32.0    Male        High School        Sales Associate         3.0
# 6701  30.0  Female  Bachelor's Degree      Financial Manager         4.0
# 6702  46.0    Male    Master's Degree      Marketing Manager        14.0
# 6703  26.0  Female        High School        Sales Executive         1.0
#
#         Salary
# 0      90000.0
# 1      65000.0
# 2     150000.0
# 3      60000.0
# ...

# %%
df.head()
# Out:
#     Age  Gender Qualification                job  Experience    Salary
# 0  32.0    Male    Bachelor's  Software Engineer         5.0   90000.0
# 1  28.0  Female           PHD       Data Analyst         3.0   65000.0
# 2  45.0    Male           PHD     Senior Manager        15.0  150000.0
# 3  36.0  Female           PHD    Sales Associate         NaN   60000.0
# 4  52.0    Male      Master's           Director        20.0  200000.0

# %%
import seaborn as s

# %%
s.kdeplot(df['Age'])
s.kdeplot(df['Experience'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>
